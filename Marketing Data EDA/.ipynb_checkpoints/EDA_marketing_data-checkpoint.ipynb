# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('marketing_data.csv')
df.head()
# Out:
#       ID  Year_Birth   Education Marital_Status      Income   Kidhome  \
# 0   1826        1970  Graduation       Divorced  $84,835.00         0
# 1      1        1961  Graduation         Single  $57,091.00         0
# 2  10476        1958  Graduation        Married  $67,267.00         0
# 3   1386        1967  Graduation       Together  $32,474.00         1
# 4   5371        1989  Graduation         Single  $21,474.00         1
#
#    Teenhome Dt_Customer  Recency  MntWines  ...  NumStorePurchases  \
# 0         0     6/16/14        0       189  ...                  6
# 1         0     6/15/14        0       464  ...                  7
# 2         1     5/13/14        0       134  ...                  5
# 3         1     5/11/14        0        10  ...                  2
# 4         0      4/8/14        0         6  ...                  2
#
#    NumWebVisitsMonth  AcceptedCmp3  AcceptedCmp4  AcceptedCmp5  AcceptedCmp1  \
# ...

# %%
df.isnull()
# Out:
#          ID  Year_Birth  Education  Marital_Status   Income   Kidhome  \
# 0     False       False      False           False     False    False
# 1     False       False      False           False     False    False
# 2     False       False      False           False     False    False
# 3     False       False      False           False     False    False
# 4     False       False      False           False     False    False
# ...     ...         ...        ...             ...       ...      ...
# 2235  False       False      False           False     False    False
# 2236  False       False      False           False     False    False
# 2237  False       False      False           False     False    False
# 2238  False       False      False           False     False    False
# 2239  False       False      False           False     False    False
#
#       Teenhome  Dt_Customer  Recency  MntWines  ...  NumStorePurchases  \
# ...

# %%
df.isnull().any()
# Out:
# ID                     False
# Year_Birth             False
# Education              False
# Marital_Status         False
#  Income                 True
# Kidhome                False
# Teenhome               False
# Dt_Customer            False
# Recency                False
# MntWines               False
# MntFruits              False
# MntMeatProducts        False
# MntFishProducts        False
# MntSweetProducts       False
# MntGoldProds           False
# NumDealsPurchases      False
# NumWebPurchases        False
# NumCatalogPurchases    False
# NumStorePurchases      False
# NumWebVisitsMonth      False
# AcceptedCmp3           False
# AcceptedCmp4           False
# AcceptedCmp5           False
# AcceptedCmp1           False
# AcceptedCmp2           False
# Response               False
# Complain               False
# Country                False
# dtype: bool

# %%
df = df.dropna()

# %%
bxplt = df.boxplot(column = ['Year_Birth'])

# %%
df2 = df[df['Year_Birth'] >= 1920]

# %%
bxplt2 = df.boxplot(column = ['MntWines'])

# %%
df3 = df2[df2['MntWines'] <= 1200]

# %%
bxplt3 = df.boxplot(column = ['MntMeatProducts'])

# %%
df3 = df3[df3['MntMeatProducts'] <= 1500]

# %%
boxplot = df3.boxplot(column = ['Year_Birth','MntWines','MntFruits','MntMeatProducts','MntFishProducts','MntSweetProducts','MntGoldProds'], rot = 90)

# %%
sns.heatmap(df3.corr(), vmin=-1, vmax=1, center= 0, cmap= 'coolwarm')
# Out:
# <AxesSubplot:>

# %%
df3['Year_Birth'].astype(int).value_counts().plot(kind = 'bar', title = 'Birth Year Counts')
# Out:
# <AxesSubplot:title={'center':'Birth Year Counts'}>

# %%
df3['Marital_Status'].value_counts().plot(kind = 'bar', title = 'Marriage Status')
# Out:
# <AxesSubplot:title={'center':'Marriage Status'}>

# %%
df3['Education'].value_counts().plot(kind = 'bar', title = 'Education')
# Out:
# <AxesSubplot:title={'center':'Education'}>

# %%
df3[' Income '] = df3[' Income '].str.replace('$', '')
df3[' Income '] = df3[' Income '].str.replace(',', '')
df3[' Income '] = df3[' Income '].astype(float)

# %%
x = df3.describe(include = 'all')

# %%
pd.set_option('display.max_columns', 28)
x
# Out:
#                   ID   Year_Birth   Education Marital_Status        Income   \
# count    2167.000000  2167.000000        2167           2167    2167.000000
# unique           NaN          NaN           5              8            NaN
# top              NaN          NaN  Graduation        Married            NaN
# freq             NaN          NaN        1100            836            NaN
# mean     5585.743424  1968.966313         NaN            NaN   51602.555607
# std      3251.696153    11.660806         NaN            NaN   24803.027258
# min         0.000000  1940.000000         NaN            NaN    1730.000000
# 25%      2812.500000  1959.500000         NaN            NaN   34925.500000
# 50%      5455.000000  1970.000000         NaN            NaN   50729.000000
# 75%      8419.000000  1977.000000         NaN            NaN   67439.000000
# max     11191.000000  1996.000000         NaN            NaN  666666.000000
#
# ...

# %%
average_customer = {'Year_Birth': 1969,
                    'Education': 'Graduation',
                    'Marital_Status': 'Married',
                    'Income': 51000,
                    'Kidhome': 0.5,
                    'Teenhome': 0.5,
                    'Country': 'SP',
                    'MntWines': 286,
                    'MntFruits': 26,
                    'MntMeatProducts': 160,
                    'MntFishProducts': 37,
                    'MntSweetProducts': 26,
                    'MntGoldProducts': 43,
                    'MostPurchases': 'Store',
                    'WebVisitsAMonth': 5
}

# %%
products = df3[['MntWines', 'MntFruits', 'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts', 'MntGoldProds']]

# %%
products.sum().plot(kind = 'bar', rot = 90)
# Out:
# <AxesSubplot:>

# %%
channels = df3[['NumDealsPurchases', 'NumWebPurchases', 'NumCatalogPurchases', 'NumStorePurchases', 'NumWebVisitsMonth']]

# %%
channels.sum().plot(kind = 'bar', rot = 90)
# Out:
# <AxesSubplot:>
